# %%
import pandas as pd
veriler = {
    'MusteriID': [1, 2, 3, 4],
    'MusteriAd': ['Kaan', 'Mehmet', 'Yusuf', 'Ahmet'],
    'KrediMiktari': [40000, 50000, 60000, 80000],
    'GecikmeGunSayisi': [3, 5, 8, 9],
    'Sektor': ['Insaat', 'Sanayi', 'Bilim', 'Hizmet']
}
tb = pd.DataFrame(veriler)
tb
zenginler = tb[tb['KrediMiktari'] > 50000]
tb ['MusteriAd']
riskli_olanlar = tb[tb['KrediMiktari'] > 50000] 
print(riskli_olanlar)
tb['Durum'] = ['TOP' if x >= 60000 else 'NORMAL' for x in tb['KrediMiktari']]
tb
tb.to_csv('banka_verileriphy.csv', index=False)
# Out:
#    MusteriID MusteriAd  KrediMiktari  GecikmeGunSayisi  Sektor
# 2          3     Yusuf         60000                 8   Bilim
# 3          4     Ahmet         80000                 9  Hizmet
